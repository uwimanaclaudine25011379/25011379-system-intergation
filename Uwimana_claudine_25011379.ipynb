# %% [markdown]
# <a href="https://colab.research.google.com/github/uwimanaclaudine25011379/25011379-system-intergation/blob/main/Uwimana_claudine_25011379.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# %%
results=requests.get('https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow')
print(results)
# Out:
# <Response [200]>

# %%
print(results.json())
# Out:
# {'items': [{'tags': ['docker', 'kubernetes', 'amazon-ecr', 'argo-workflows', 'argo'], 'owner': {'account_id': 21219170, 'reputation': 23, 'user_id': 15606163, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/255a11bc93d596ec2306ca897fb899b3?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'rewa', 'link': 'https://stackoverflow.com/users/15606163/rewa'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1752320050, 'creation_date': 1752320050, 'question_id': 79699234, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79699234/why-argoworkflows-multi-app-docker-build-image-with-kaniko-fails', 'title': 'why Argoworkflows multi-app-docker-build image with kaniko fails'}, {'tags': ['vue.js', 'vuejs3'], 'owner': {'account_id': 14929290, 'reputation': 541, 'user_id': 10779129, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/de5f77a69d67c235fd9e60bc3b02a79
# ...

# %%
print(results.json()['items'])
# Out:
# [{'tags': ['docker', 'kubernetes', 'amazon-ecr', 'argo-workflows', 'argo'], 'owner': {'account_id': 21219170, 'reputation': 23, 'user_id': 15606163, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/255a11bc93d596ec2306ca897fb899b3?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'rewa', 'link': 'https://stackoverflow.com/users/15606163/rewa'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1752320050, 'creation_date': 1752320050, 'question_id': 79699234, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79699234/why-argoworkflows-multi-app-docker-build-image-with-kaniko-fails', 'title': 'why Argoworkflows multi-app-docker-build image with kaniko fails'}, {'tags': ['vue.js', 'vuejs3'], 'owner': {'account_id': 14929290, 'reputation': 541, 'user_id': 10779129, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/de5f77a69d67c235fd9e60bc3b02a794?s=256&d=
# ...

# %%
print(results.json()['items'])
# Out:
# [{'tags': ['docker', 'kubernetes', 'amazon-ecr', 'argo-workflows', 'argo'], 'owner': {'account_id': 21219170, 'reputation': 23, 'user_id': 15606163, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/255a11bc93d596ec2306ca897fb899b3?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'rewa', 'link': 'https://stackoverflow.com/users/15606163/rewa'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1752320050, 'creation_date': 1752320050, 'question_id': 79699234, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79699234/why-argoworkflows-multi-app-docker-build-image-with-kaniko-fails', 'title': 'why Argoworkflows multi-app-docker-build image with kaniko fails'}, {'tags': ['vue.js', 'vuejs3'], 'owner': {'account_id': 14929290, 'reputation': 541, 'user_id': 10779129, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/de5f77a69d67c235fd9e60bc3b02a794?s=256&d=
# ...

# %%
for questions in results.json()['items']:
  print(questions['title'])
  print(questions['link'])
  print()
# Out:
# why Argoworkflows multi-app-docker-build image with kaniko fails
# https://stackoverflow.com/questions/79699234/why-argoworkflows-multi-app-docker-build-image-with-kaniko-fails
#
# Getting write operation failed warning with refs
# https://stackoverflow.com/questions/77951785/getting-write-operation-failed-warning-with-refs
#
# Cleaning VSCode profiles Folder &amp; Workspaces
# https://stackoverflow.com/questions/79272316/cleaning-vscode-profiles-folder-workspaces
#
# Extracting visible text from an epub viewer using epubjs
# https://stackoverflow.com/questions/79699232/extracting-visible-text-from-an-epub-viewer-using-epubjs
#
# Import module installed with npm without node.js
# https://stackoverflow.com/questions/79699231/import-module-installed-with-npm-without-node-js
#
# How to prevent filtered component from re-rendering over and over?
# https://stackoverflow.com/questions/79674218/how-to-prevent-filtered-component-from-re-rendering-over-and-over
#
# ...

# %%
for questions in results.json()['items']:
  if questions[ 'answer_count']==0:
   print(questions['title'])
   print(questions['link'])
else:
   print("skipped")
   print()
# Out:
# why Argoworkflows multi-app-docker-build image with kaniko fails
# https://stackoverflow.com/questions/79699234/why-argoworkflows-multi-app-docker-build-image-with-kaniko-fails
# Extracting visible text from an epub viewer using epubjs
# https://stackoverflow.com/questions/79699232/extracting-visible-text-from-an-epub-viewer-using-epubjs
# Import module installed with npm without node.js
# https://stackoverflow.com/questions/79699231/import-module-installed-with-npm-without-node-js
# Will requests to my site lag and work slowly in django while waiting for celery results?
# https://stackoverflow.com/questions/79698019/will-requests-to-my-site-lag-and-work-slowly-in-django-while-waiting-for-celery
# How to use relative path to get file in C drive but the current program file is in D drive?
# https://stackoverflow.com/questions/79699163/how-to-use-relative-path-to-get-file-in-c-drive-but-the-current-program-file-is
# Why does this CMake list variable expansion not behave as expected?
# ...
